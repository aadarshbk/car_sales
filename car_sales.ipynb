# %%
import pandas as pd
df=pd.read_csv('Norway_car_sales_by_brands.csv')

# %%
df

# %%
df['Make'].unique()

# %%
# Assuming df is your DataFrame
column_names = df.columns.tolist()
print(column_names)

# %%
import pandas as pd

# Assuming df is your DataFrame
null_values_count = df.isnull().sum()

print("Number of null values in each column:")
print(null_values_count)

# %%
dataframes = df.dropna()

# %%
null_values_count = dataframes.isnull().sum()

print("Number of null values in each column:")
print(null_values_count)

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the data
filtered_df = df[df['Quantity'] > 800]

plt.bar(filtered_df['Make'], filtered_df['Quantity'])
plt.xlabel('Car brand sold in Norway')
plt.ylabel('Quantity of cars sold')
plt.title('Total sales by car brand (Quantity > 800)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
